# %% [markdown]
# This notebook calculates the impact of NHS price concessions in 2018 on organisations that are not CCGs.

# %%
import pandas as pd
import numpy as np
GBQ_PROJECT_ID = '620265099307'

# %%
## SQL query to extract additonal costs of NHS price concessions. 
## This is a modfied version of the SQL query from OpenPrescribing.net NHS price concession calculator site i.e. done at a "organisational level" 
q='''SELECT
  ncso.date AS month,
  product.bnf_code AS bnf_code,
  product.name AS product_name,
  rx.quantity AS quantity,
  rx.pct AS pct,
  ccg.org_type,
  ccg.name,
  dt.price_pence
    * rx.quantity
    * CASE WHEN
        -- For some presentations "quantity" means "number of packs" rather
        -- than e.g. tablets. In these cases we don't want to divide by the
        -- quantity value of a pack. This is implemented via a flag in our
        -- databse but this data isn't in BiqQuery so we just have a hardcoded
        -- list of BNF codes here
        product.bnf_code in ('0206010F0AACJCJ')
      THEN
        1
      ELSE
        1 / vmpp.qtyval
      END
    -- This is the "discount factor" which applies the National Average 7.2%
    -- discount to estimate Actual Cost from Net Ingredient Cost and also
    -- converts figures from pence to pounds
    * 0.00928
    AS tariff_cost,
  COALESCE(ncso.price_concession_pence - dt.price_pence, 0)
    * rx.quantity
    * CASE WHEN
        product.bnf_code in ('0206010F0AACJCJ')
      THEN
        1
      ELSE
        1 / vmpp.qtyval
      END
    * 0.00928
    AS additional_cost,
  ncso.date != rx.month AS is_projection
FROM
  dmd.ncsoconcession AS ncso
JOIN
  dmd.tariffprice AS dt
ON
  ncso.vmpp = dt.vmpp AND ncso.date = dt.date
JOIN
  dmd.product AS product
ON
  dt.product=product.dmdid
JOIN
  dmd.vmpp AS vmpp
ON
  vmpp.vppid=ncso.vmpp
JOIN
  hscic.presentation AS presentation
ON
  presentation.bnf_code = product.bnf_code
JOIN
  hscic.prescribing AS rx
ON
  rx.bnf_code = product.bnf_code
JOIN
  hscic.ccgs AS ccg #this joins to our CCG organisational data
ON
  rx.pct = ccg.code
AND
-- Where we have prescribing data for the corresponding month we use
-- that, otherwise we use the latest month of prescribing data to
-- produce an estimate
(
  rx.month = ncso.date
  OR
  (
    -- This should be set to the latest date for which we have prescribing
    -- data
    rx.month = TIMESTAMP('2018-12-01')
    AND
    ncso.date > rx.month
  )
)'''
    
all_ncso = pd.read_gbq(q, GBQ_PROJECT_ID, verbose = False, dialect = 'standard')
# Out:
# C:\Users\bmackenna\Anaconda3\lib\site-packages\pandas_gbq\gbq.py:556: FutureWarning: verbose is deprecated and will be removed in a future version. Set logging level in order to vary verbosity
#   "verbosity", FutureWarning, stacklevel=1)

# %% [markdown]
# #### Importing organisational for non-CCGs naming data from NHS Digital ODS Service

# %%
## import councils from NHS Digital ODS codes
councils = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\jupyter-notebooks\nonCCG Concessions\Lauth.csv')
councils['pct'] = councils['pct'].astype('str')
councils.head(5)
# Out:
#   pct                 name national_grouping high_level_health_geography  \
# 0  12  ISLE OF ANGLESEY UA               W00                         Q99
# 1  14           GWYNEDD UA               W00                         Q99
# 2  16             CONWY UA               W00                         Q99
# 3  18      DENBIGHSHIRE UA               W00                         Q99
# 4  20        FLINTSHIRE UA               W00                         Q99
#
#      address line 1     Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0   COUNCIL OFFICES            NaN        NaN   LLANGEFNI    GWYNEDD
# 1  SHIREHALL STREET            NaN        NaN  CAERNARFON    GWYNEDD
# 2         BODLONDEB    BANGOR ROAD        NaN       CONWY    GWYNEDD
# 3   COUNCIL OFFICES  WYNNSTAY ROAD        NaN      RUTHIN      CLWYD
# 4       COUNTY HALL            NaN        NaN        MOLD      CLWYD
#
#    postcode  open_date  close_date  null organisation sub-type code
# 0  LL77 7TW   19960401         NaN   NaN                          H
# 1  LL55 1SH   19960401         NaN   NaN                          H
# 2  LL32 8DU   19960401         NaN   NaN                          H
# 3  LL15 1YN   19960401         NaN   NaN                          H
# 4   CH7 6NB   19960401         NaN   NaN                          H

# %%
## import "independent providers" from NHS Digital ODS codes
independent_providers = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\jupyter-notebooks\nonCCG Concessions\ephp.csv')
independent_providers.head(5)
# Out:
#    pct                                          name national_grouping  \
# 0  AA4                               INTRAHEALTH LTD               Y54
# 1  AA5  COMPASS WELLBEING COMMUNITY INTEREST COMPANY               Y56
# 2  AA6                  ASSISTED CONCEPTION UNIT LTD               Y56
# 3  AA7                         LEYLAND PHYSIOTHERAPY               Y54
# 4  AA8                                     SMART CJS               Y59
#
#   high_level_health_geography                   address line 1  \
# 0                         Q74  1ST FLOOR, WILLIAM BROWN CENTRE
# 1                         Q71        STEELS LANE HEALTH CENTRE
# 2                         Q71                LEYTONSTONE HOUSE
# 3                         Q84                      83 BOW LANE
# 4                         Q87                       BUILDING B
#
#                     Unnamed: 5               Unnamed: 6  Unnamed: 7  \
# 0                    MANOR WAY                      NaN    PETERLEE
# 1      384-388 COMMERCIAL ROAD                      NaN      LONDON
# 2                  LEYTONSTONE                      NaN      LONDON
# 3                          NaN                      NaN     LEYLAND
# 4  KIRTLINGTON BUSINESS CENTRE  SLADE FARM, KIRTLINGTON  KIDLINGTON
#
#        Unnamed: 8  postcode  open_date  close_date
# 0   COUNTY DURHAM   SR8 5TW   20130401         NaN
# 1  GREATER LONDON    E1 0LR   20130401         NaN
# 2  GREATER LONDON   E11 1GA   20130401         NaN
# 3      LANCASHIRE  PR25 4YB   20130401         NaN
# 4     OXFORDSHIRE   OX5 3JA   20130401         NaN

# %%
## import hospitals from NHS Digital ODS codes
hospital_providers = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\jupyter-notebooks\nonCCG Concessions\etr.csv')
hospital_providers.head(5)
# Out:
#    pct                                               name national_grouping  \
# 0  R0A         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST               Y54
# 1  R1A           WORCESTERSHIRE HEALTH AND CARE NHS TRUST               Y55
# 2  R1C                                   SOLENT NHS TRUST               Y59
# 3  R1D              SHROPSHIRE COMMUNITY HEALTH NHS TRUST               Y55
# 4  R1E  STAFFORDSHIRE AND STOKE ON TRENT PARTNERSHIP N...               Y55
#
#   high_level_health_geography                 address line 1  \
# 0                         Q83                  COBBETT HOUSE
# 1                         Q77             ISAAC MADDOX HOUSE
# 2                         Q87  SOLENT NHS TRUST HEADQUARTERS
# 3                         Q76             WILLIAM FARR HOUSE
# 4                         Q76       2ND FLOOR, MORSTON HOUSE
#
#                      Unnamed: 5      Unnamed: 6            Unnamed: 7  \
# 0                   OXFORD ROAD             NaN            MANCHESTER
# 1  SHRUB HILL INDUSTRIAL ESTATE             NaN             WORCESTER
# 2               HIGHPOINT VENUE  BURSLEDON ROAD           SOUTHAMPTON
# 3               MYTTON OAK ROAD             NaN            SHREWSBURY
# 4                           NaN             NaN  NEWCASTLE-UNDER-LYME
#
#            Unnamed: 8  postcode  open_date
# 0  GREATER MANCHESTER   M13 9WL   20171001
# 1      WORCESTERSHIRE   WR4 9RW   20110701
# 2           HAMPSHIRE  SO19 8BR   20110401
# 3          SHROPSHIRE   SY3 8XL   20110701
# 4       STAFFORDSHIRE   ST5 1QG   20110901

# %%
## Selecting only nonCCG organisations to work with
nonccg_ncso  = all_ncso.loc[all_ncso.org_type !='CCG']
nonccg_ncso.head()
# Out:
#          month         bnf_code  \
# 98  2018-04-01  0402010ADAAAAAA
# 225 2018-04-01  0402010ADAAADAD
# 254 2018-04-01  0410030A0AAADAD
# 696 2018-08-01  1304000Y0AAAAAA
# 697 2018-08-01  1304000Y0AAAAAA
#
#                                         product_name  quantity  pct org_type  \
# 98                         Aripiprazole 10mg tablets       129  RTV  Unknown
# 225                         Aripiprazole 5mg tablets       266  RYG  Unknown
# 254  Buprenorphine 2mg sublingual tablets sugar free       226  218  Unknown
# 696                            Mometasone 0.1% cream        90  NCN  Unknown
# 697                            Mometasone 0.1% cream        90  NDL  Unknown
#
#      name  tariff_cost  additional_cost  is_projection
# 98   None     8.508103         4.531954          False
# 225  None    20.893920         4.231680          False
# 254  None    27.863863        12.583680          False
# 696  None     4.952736         1.645344          False
# 697  None     4.955520         3.034560          False

# %%
## ensuring the format is consistent for pounds and pence
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
## Restricting data to 2018 calendar year
nonccg_ncso_thisyear = nonccg_ncso.loc[(nonccg_ncso["month"]>="2018-01-01") & (nonccg_ncso["month"]<="2018-12-01")]
nonccg_ncso_thisyear.head()
# Out:
#          month         bnf_code  \
# 98  2018-04-01  0402010ADAAAAAA
# 225 2018-04-01  0402010ADAAADAD
# 254 2018-04-01  0410030A0AAADAD
# 696 2018-08-01  1304000Y0AAAAAA
# 697 2018-08-01  1304000Y0AAAAAA
#
#                                         product_name  quantity  pct org_type  \
# 98                         Aripiprazole 10mg tablets       129  RTV  Unknown
# 225                         Aripiprazole 5mg tablets       266  RYG  Unknown
# 254  Buprenorphine 2mg sublingual tablets sugar free       226  218  Unknown
# 696                            Mometasone 0.1% cream        90  NCN  Unknown
# 697                            Mometasone 0.1% cream        90  NDL  Unknown
#
#      name  tariff_cost  additional_cost  is_projection
# 98   None         8.51             4.53          False
# 225  None        20.89             4.23          False
# 254  None        27.86            12.58          False
# 696  None         4.95             1.65          False
# 697  None         4.96             3.03          False

# %% [markdown]
# ### 2018 Impact - all months, all orgs, all meds

# %%
## Total cost impact of price consessions this year to nonCCG organisations. This will return an "unknown name" but is all nonCCGs
nonccg_ncso_thisyear.groupby('org_type').sum().sort_values(by = 'additional_cost', ascending = False)
# Out:
#           quantity  tariff_cost  additional_cost  is_projection
# org_type
# Unknown    9250711   1276379.41       5627890.92          False

# %%
## nonccg organisation spend grouped by indivual preparations
nonccg_ncso_thisyear.groupby('product_name').sum().sort_values(by = 'additional_cost', ascending = False)
# Out:
#                                                     quantity  tariff_cost  \
# product_name
# Buprenorphine 8mg sublingual tablets sugar free      2662817    682062.04
# Buprenorphine 2mg sublingual tablets sugar free      3450506    414783.01
# Phenoxymethylpenicillin 125mg/5ml oral solution       561600     17613.44
# Phenoxymethylpenicillin 250mg/5ml oral solution       331900     13230.31
# Naproxen 500mg tablets                                 48466      1989.28
# Diamorphine 30mg powder for solution for inject...      7637     16243.72
# Metronidazole 400mg tablets                            43417      4715.31
# Risperidone 500microgram tablets                       69363      1931.19
# Diamorphine 10mg powder for solution for inject...      7622     16571.03
# Risperidone 1mg tablets                                30520       825.03
# Ondansetron 4mg tablets                                 3744       283.51
# Trimethoprim 50mg/5ml oral suspension sugar free      312610      6550.96
# Tadalafil 5mg tablets                                   5418      1243.50
# Lamotrigine 100mg tablets                              15991      1102.42
# Mometasone 0.1% ointment                              115560      6134.43
# Latanoprost 50micrograms/ml eye drops                   1017       624.05
# Naproxen 250mg tablets                                 48990      1418.40
# Phenoxymethylpenicillin 125mg/5ml oral solution...    163800      7554.72
# Phenoxymethylpenicillin 250mg/5ml oral solution...    155000      8256.42
# Risperidone 2mg tablets                                11259       252.31
# Aripiprazole 5mg tablets                               32092      1726.31
# Furosemide 40mg tablets                                31702       584.97
# Mometasone 0.1% cream                                  66500      3494.99
# Propranolol 10mg tablets                               32650       971.40
# Aripiprazole 10mg tablets                              25928      1393.74
# Eplerenone 25mg tablets                                 3969       593.26
# Lamotrigine 200mg tablets                               5841       549.11
# Lamotrigine 50mg tablets                               19979       860.69
# Quetiapine 25mg tablets                                43384      1657.38
# Risperidone 3mg tablets                                 3631        97.03
# ...                                                      ...          ...
# Propranolol 80mg tablets                                 678        14.34
# Rasagiline 1mg tablets                                   461        38.96
# Clomipramine 10mg capsules                               710        31.06
# Ramipril 1.25mg tablets                                 1558        73.83
# Amitriptyline 50mg tablets                              1204        98.16
# Atorvastatin 80mg tablets                               6324       358.41
# Nortriptyline 25mg tablets                               179         7.56
# Metronidazole 200mg tablets                              688        69.01
# Sevelamer 800mg tablets                                   84        13.65
# Duloxetine 40mg gastro-resistant capsules                   False
# Citalopram 40mg/ml oral drops sugar free                    False
# Lacidipine 4mg tablets                                      False
# Doxazosin 2mg tablets                                       False
# Mirtazapine 45mg orodispersible tablets                     False
# Pregabalin 225mg capsules                                   False
# Oxazepam 15mg tablets                                       False
# Lacidipine 2mg tablets                                      False
# Glyceryl trinitrate 400micrograms/dose pump sub...          False
# Metoprolol 50mg tablets                                     False
# Mirtazapine 30mg orodispersible tablets                     False
# Telmisartan 20mg tablets                                    False
#
# [181 rows x 4 columns]

# %%
## monthly impact of price concessions for nonCCG organisations
nonccg_ncso_thisyear.groupby('month').sum()
# Out:
#             quantity  tariff_cost  additional_cost  is_projection
# month
# 2018-01-01    222752     14003.23         12341.81          False
# 2018-02-01    527126     21353.33         20029.98          False
# 2018-03-01    654052     24725.51         23698.88          False
# 2018-04-01    988802    126949.47         44418.85          False
# 2018-05-01    972980    133551.95        870681.17          False
# 2018-06-01    795898    122896.73        564727.31          False
# 2018-07-01    830210    121639.71        626966.71          False
# 2018-08-01    820650    140137.93        480764.05          False
# 2018-09-01    764163    131730.37        738909.13          False
# 2018-10-01    831372    148511.44        802503.61          False
# 2018-11-01    986748    143168.97        732430.48          False
# 2018-12-01    855958    147710.77        710418.94          False

# %% [markdown]
# ### Impact on individual organisations

# %%
## assess impact on each organisation "PCT" i.e. nonCCG organisations
nonccg_ncso_orgs = nonccg_ncso_thisyear.groupby('pct').sum().sort_values(by = 'additional_cost', ascending = False)

# %%
## adding in council names from organisational data name
add_councils = nonccg_ncso_orgs.reset_index().merge(councils[['pct','name']],  how = "outer", on = 'pct')

# %%
## adding in independent provider names
add_indprov = add_councils.merge(independent_providers[['pct','name']],  how="outer", on='pct', suffixes=("_council","_independent_provider"))

# %%
## finaly adding hospital name
all_nonccg_orgs = add_indprov.merge(hospital_providers[['pct','name']],  how="outer", on='pct')

# %%
## creating new single column with  organisation name so no blanks
all_nonccg_orgs['organisation_name'] = all_nonccg_orgs['name_council'].fillna('') + all_nonccg_orgs['name_independent_provider'].fillna('') + all_nonccg_orgs['name'].fillna('')
all_nonccg_orgs.head(5)
# Out:
#    pct   quantity  tariff_cost  additional_cost is_projection  \
# 0  NMS 2321084.00    420902.13       2091871.32         False
# 1  NKI  652671.00    128192.32        582024.50         False
# 2  NI3  278206.00     47257.92        226144.28         False
# 3  212  201394.00     36833.46        181742.50         False
# 4  RX4  197914.00     35077.43        174186.77         False
#
#          name_council name_independent_provider  \
# 0                 NaN        CHANGE, GROW, LIVE
# 1                 NaN             TURNING POINT
# 2                 NaN                 ADDACTION
# 3  LEEDS CITY COUNCIL                       NaN
# 4                 NaN                       NaN
#
#                                                 name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  NORTHUMBERLAND, TYNE AND WEAR NHS FOUNDATION T...
#
#                                    organisation_name
# 0                                 CHANGE, GROW, LIVE
# 1                                      TURNING POINT
# 2                                          ADDACTION
# 3                                 LEEDS CITY COUNCIL
# 4  NORTHUMBERLAND, TYNE AND WEAR NHS FOUNDATION T...

# %%
price_concession_impact_nonCCG = all_nonccg_orgs[['pct', 'organisation_name', 'tariff_cost', 'additional_cost']]
price_concession_impact_nonCCG
# Out:
#       pct                                  organisation_name  tariff_cost  \
# 0     NMS                                 CHANGE, GROW, LIVE    420902.13
# 1     NKI                                      TURNING POINT    128192.32
# 2     NI3                                          ADDACTION     47257.92
# 3     212                                 LEEDS CITY COUNCIL     36833.46
# 4     RX4  NORTHUMBERLAND, TYNE AND WEAR NHS FOUNDATION T...     35077.43
# 5     112                              MIDDLESBROUGH COUNCIL     34264.28
# 6     107                   NEWCASTLE-UPON-TYNE CITY COUNCIL     24863.42
# 7     NL1                    SPECTRUM COMMUNITY HEALTH - CIC     24673.03
# 8     DG3                                  THE FORWARD TRUST     23410.78
# 9     114                   STOCKTON-ON-TEES BOROUGH COUNCIL     22778.26
# 10    116                              DURHAM COUNTY COUNCIL     23334.33
# 11    ARG                          WESTMINISTER DRUG PROJECT     20419.97
# 12    110                            SUNDERLAND CITY COUNCIL     19135.17
# 13    RXM         DERBYSHIRE HEALTHCARE NHS FOUNDATION TRUST     18980.00
# 14    AKQ                                 DELPHI MEDICAL LTD     18037.11
# 15    NR5                                 LIVEWELL SOUTHWEST     20491.66
# 16    RXE  ROTHERHAM DONCASTER AND SOUTH HUMBER NHS FOUND...     15004.21
# 17    215                    KINGSTON-UPON-HULL CITY COUNCIL     14749.50
# 18    AJ6                                          HUMANKIND     12852.78
# 19    211                                   KIRKLEES COUNCIL     13757.94
# 20    414                        STOKE-ON-TRENT CITY COUNCIL     13631.12
# 21    DLA                                          CRANSTOUN     12394.63
# 22    310             STOCKPORT METROPOLITAN BOROUGH COUNCIL     11555.99
# 23    AKV                         SWANSWELL CHARITABLE TRUST     10623.80
# 24    322               WARRINGTON BOROUGH COUNCIL (UNITARY)     10815.52
# 25    DNK                  TOGETHER DRUG AND ALCOHOL SERVICE      9189.88
# 26    218                     NORTH YORKSHIRE COUNTY COUNCIL      9113.01
# 27    313                 WIGAN METROPOLITAN BOROUGH COUNCIL     11761.82
# 28    DEC                            THE SOCIETY OF ST JAMES      7849.19
# 29    RXA  CHESHIRE AND WIRRAL PARTNERSHIP NHS FOUNDATION...     13593.69
# ...   ...                                                ...          ...
# 2214  RWJ                     STOCKPORT NHS FOUNDATION TRUST          nan
# 2215  RWP           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST          nan
# 2216  RWR  HERTFORDSHIRE PARTNERSHIP UNIVERSITY NHS FOUND...          nan
# 2217  RWV                        DEVON PARTNERSHIP NHS TRUST          nan
# 2218  RWW  WARRINGTON AND HALTON HOSPITALS NHS FOUNDATION...          nan
# 2219  RWY   CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST          nan
# 2220  RX1          NOTTINGHAM UNIVERSITY HOSPITALS NHS TRUST          nan
# 2221  RX2            SUSSEX PARTNERSHIP NHS FOUNDATION TRUST          nan
# 2222  RX3    TEES, ESK AND WEAR VALLEYS NHS FOUNDATION TRUST          nan
# 2223  RX7             NORTH WEST AMBULANCE SERVICE NHS TRUST          nan
# 2224  RX8              YORKSHIRE AMBULANCE SERVICE NHS TRUST          nan
# 2225  RX9          EAST MIDLANDS AMBULANCE SERVICE NHS TRUST          nan
# 2226  RXF                  MID YORKSHIRE HOSPITALS NHS TRUST          nan
# 2227  RXL  BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST          nan
# 2228  RXN  LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION T...          nan
# 2229  RXP  COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST          nan
# 2230  RXR                EAST LANCASHIRE HOSPITALS NHS TRUST          nan
# 2231  RXT  BIRMINGHAM AND SOLIHULL MENTAL HEALTH NHS FOUN...          nan
# 2232  RXV  GREATER MANCHESTER MENTAL HEALTH NHS FOUNDATIO...          nan
# 2233  RXW          SHREWSBURY AND TELFORD HOSPITAL NHS TRUST          nan
# 2234  RXX  SURREY AND BORDERS PARTNERSHIP NHS FOUNDATION ...          nan
# 2235  RXY  KENT AND MEDWAY NHS AND SOCIAL CARE PARTNERSHI...          nan
# 2236  RY9  HOUNSLOW AND RICHMOND COMMUNITY HEALTHCARE NHS...          nan
# 2237  RYA  WEST MIDLANDS AMBULANCE SERVICE NHS FOUNDATION...          nan
# 2238  RYC        EAST OF ENGLAND AMBULANCE SERVICE NHS TRUST          nan
# 2239  RYD  SOUTH EAST COAST AMBULANCE SERVICE NHS FOUNDAT...          nan
# 2240  RYE  SOUTH CENTRAL AMBULANCE SERVICE NHS FOUNDATION...          nan
# 2241  RYR      WESTERN SUSSEX HOSPITALS NHS FOUNDATION TRUST          nan
# 2242  RYT                      PUBLIC HEALTH WALES NHS TRUST          nan
# 2243  RYV        CAMBRIDGESHIRE COMMUNITY SERVICES NHS TRUST          nan
#
#       additional_cost
# 0          2091871.32
# 1           582024.50
# 2           226144.28
# 3           181742.50
# 4           174186.77
# 5           164438.04
# 6           124219.57
# 7           122254.48
# 8           116849.06
# 9           113859.05
# 10          113715.67
# 11          102133.12
# 12           95970.38
# 13           92836.56
# 14           90252.92
# 15           74896.55
# 16           73648.59
# 17           67434.86
# 18           67408.74
# 19           66567.39
# 20           66210.54
# 21           61154.84
# 22           57318.39
# 23           53181.93
# 24           51624.80
# 25           50585.26
# 26           44821.40
# 27           44282.21
# 28           38906.27
# 29           37291.36
# ...               ...
# 2214              nan
# 2215              nan
# 2216              nan
# 2217              nan
# 2218              nan
# 2219              nan
# 2220              nan
# 2221              nan
# 2222              nan
# 2223              nan
# 2224              nan
# 2225              nan
# 2226              nan
# 2227              nan
# 2228              nan
# 2229              nan
# 2230              nan
# 2231              nan
# 2232              nan
# 2233              nan
# 2234              nan
# 2235              nan
# 2236              nan
# 2237              nan
# 2238              nan
# 2239              nan
# 2240              nan
# 2241              nan
# 2242              nan
# 2243              nan
#
# [2244 rows x 4 columns]

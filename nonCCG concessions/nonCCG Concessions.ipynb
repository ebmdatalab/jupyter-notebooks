# %%
import pandas as pd
import numpy as np
GBQ_PROJECT_ID = '620265099307'

# %%
## SQL query to extract additonal costs of NHS price concessions  
q='''
  #this first query is for selecting data for prescribing data already available to calculate concession impact
SELECT
  ncso.date AS month,
  rx.pct,
  ccg.org_type,
  ccg.name,
  rx.bnf_name,
  rx.bnf_code,
  SUM(quantity) AS quantity,
  SUM(quantity*ncso.add_cost_per_qty*0.928) AS add_cost #This is to adjust for a national average discount of 7.2%
FROM
  `hscic.normalised_prescribing_standard` AS rx #this is our standard prescribing file with historical data
JOIN
  `dmd.ncso_calculator` AS ncso #this prepopulated data on impact of price concessions
ON
  rx.bnf_code = ncso.bnf_code #this is joining medicines info from our prescribing file to price concession data
  AND rx.month = ncso.date #this ensures it joins on the correct date
JOIN
  hscic.ccgs AS ccg #this joins to our CCG organisational data
ON
  rx.pct = ccg.code
GROUP BY
  rx.pct,
  ccg.org_type,
  ccg.name,
  rx.bnf_code,
  rx.bnf_name,
  ncso.date,
  ncso.add_cost_per_qty
UNION ALL
  #this attaches the query below which estimates impact of price concessions where prescribing data is not yet available i.e. a projection
SELECT
  ncso.date,
  rx.pct,
  ccg.org_type,
  ccg.name,
  rx.bnf_name,
  rx.bnf_code,
  SUM(quantity) AS quantity,
  SUM(quantity*ncso.add_cost_per_qty*0.928) AS add_cost
FROM
  `hscic.normalised_prescribing_standard_latest_month` AS rx #this uses a dynamic view which always shows the latest month of prescribing data available to project price concessions
JOIN
  `dmd.ncso_calculator` AS ncso
ON
  rx.bnf_code = ncso.bnf_code
JOIN
  hscic.ccgs AS ccg
ON
  rx.pct = ccg.code
WHERE
  #this identifies which months we have price concession data for but not prescribing data
  ncso.date>(
  SELECT
    MAX(rx1.month)
  FROM
    hscic.normalised_prescribing_standard AS rx1)
GROUP BY
  rx.pct,
  ccg.org_type,
  ccg.name,
  rx.bnf_code,
  rx.bnf_name,
  ncso.date,
  ncso.add_cost_per_qty'''
   

    
all_ncso = pd.read_gbq(q, GBQ_PROJECT_ID, verbose = False, dialect = 'standard')
# Out:
# C:\Users\bmackenna\Anaconda3\lib\site-packages\pandas_gbq\gbq.py:556: FutureWarning: verbose is deprecated and will be removed in a future version. Set logging level in order to vary verbosity
#   "verbosity", FutureWarning, stacklevel=1)

# %%
## Selecting nonCCG organisations to work 
nonccg_ncso  = all_ncso.loc[all_ncso.org_type !='CCG']
nonccg_ncso.head()
# Out:
#         month  pct org_type  name                                  bnf_name  \
# 3  2015-08-01  RM1  Unknown  None  Diclofenac Sod_Tab E/C 50mg
# 17 2015-08-01  NDA  Unknown  None  Digoxin_Tab 62.5mcg
# 22 2015-08-01  RY5  Unknown  None  Diclofenac Sod_Tab E/C 50mg
# 23 2015-08-01  NL1  Unknown  None  Diclofenac Sod_Tab E/C 50mg
# 35 2015-08-01  AD9  Unknown  None  Chlorphenamine Mal_Oral Soln 2mg/5ml
#
#            bnf_code  quantity   add_cost
# 3   1001010C0AAAEAE       287  18.072800
# 17  0201010F0AAADAD        28   1.531200
# 22  1001010C0AAAEAE        15   0.944571
# 23  1001010C0AAAEAE        21   1.322400
# 35  0304010G0AAABAB       300   1.688960

# %% [markdown]
# # 2018 Impact - all months, all orgs, all meds

# %%
## ensuring the format is consistent for pounds and pence
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
## Restricting data to 2018 calendar year
nonccg_ncso_thisyear = nonccg_ncso.loc[(nonccg_ncso["month"]>="2018-01-01") & (nonccg_ncso["month"]<="2018-12-01")]
nonccg_ncso_thisyear.head()
# Out:
#           month  pct org_type  name                           bnf_name  \
# 2503 2018-08-01  NQH  Unknown  None         Fexofenadine HCl_Tab 180mg
# 2511 2018-08-01  NI3  Unknown  None  Buprenorphine_Tab Subling 2mg S/F
# 2534 2018-08-01  216  Unknown  None  Buprenorphine_Tab Subling 2mg S/F
# 2541 2018-08-01  NKB  Unknown  None              Sumatriptan_Tab 100mg
# 2545 2018-08-01  723  Unknown  None  Buprenorphine_Tab Subling 2mg S/F
#
#              bnf_code  quantity  add_cost
# 2503  0304010E0AAABAB      1012      7.83
# 2511  0410030A0AAADAD     17593   8979.47
# 2534  0410030A0AAADAD      1431    730.38
# 2541  0407041T0AAACAC        24      2.38
# 2545  0410030A0AAADAD      2485   1268.34

# %%
## Total cost impact of price consessions this year to nonCCG organisations. This will return an "unknown name"
nonccg_ncso_thisyear.groupby('org_type').sum().sort_values(by = 'add_cost', ascending = False)
# Out:
#           quantity   add_cost
# org_type
# Unknown    9290025 5632136.09

# %%
## nonccg organisations grouped by indivual preparations
nonccg_ncso_thisyear.groupby('bnf_name').sum().sort_values(by = 'add_cost', ascending = False)
# Out:
#                                           quantity   add_cost
# bnf_name
# Buprenorphine_Tab Subling 8mg S/F          2662809 3646351.27
# Buprenorphine_Tab Subling 2mg S/F          3450504 1823929.34
# Phenoxymethylpenicillin_Soln 125mg/5ml      561600   18634.74
# Phenoxymethylpenicillin_Soln 250mg/5ml      331900    9179.18
# Naproxen_Tab 500mg                           53030    8421.66
# Diamorph HCl_Inj 30mg Amp                     7637    7172.18
# Metronidazole_Tab 400mg                      43703    6787.20
# Risperidone_Tab 500mcg                       69255    6332.99
# Diamorph HCl_Inj 10mg Amp                     7622    6285.61
# Risperidone_Tab 1mg                          30814    5136.54
# Ondansetron HCl_Tab 4mg                       3886    4473.48
# Trimethoprim_Oral Susp 50mg/5ml S/F         312850    4145.75
# Tadalafil_Tab 5mg                             5502    3973.93
# Latanoprost_Eye Dps 50mcg/ml                  1317    3937.54
# Lamotrigine_Tab 100mg                        16943    3800.76
# Mometasone Fur_Oint 0.1%                    115560    3519.70
# Naproxen_Tab 250mg                           52154    3297.48
# Phenoxymethylpenicillin_Soln 125mg/5mlSF    163800    2955.12
# Phenoxymethylpenicillin_Soln 250mg/5mlSF    155000    2520.20
# Risperidone_Tab 2mg                          11590    2496.99
# Furosemide_Tab 40mg                          34684    2399.05
# Aripiprazole_Tab 5mg                         32015    2273.47
# Mometasone Fur_Crm 0.1%                      66500    2056.81
# Propranolol HCl_Tab 10mg                     33364    1937.97
# Aripiprazole_Tab 10mg                        25760    1825.14
# Eplerenone_Tab 25mg                           3969    1806.20
# Lamotrigine_Tab 50mg                         21869    1737.66
# Lamotrigine_Tab 200mg                         5953    1693.74
# Risperidone_Tab 3mg                           3801    1496.77
# Propranolol HCl_Tab 40mg                     26835    1491.40
# ...                                            ...        ...
# Propranolol HCl_Tab 80mg                       678      21.79
# Rasagiline Mesil_Tab 1mg                       461      20.12
# Clomipramine HCl_Cap 10mg                      710      19.77
# Telmisartan_Tab 40mg                           184      19.65
# Ramipril_Tab 1.25mg                           1558      17.57
# Amitriptyline HCl_Tab 50mg                    1204      16.76
# Atorvastatin_Tab 80mg                         6324      14.65
# Nortriptyline_Tab 25mg                         179      13.36
# Metronidazole_Tab 200mg                        688      13.07
# Sevelamer_Tab 800mg                             84      12.34
# Lercanidipine HCl_Tab 10mg                     351      11.98
# Propylthiouracil_Tab 50mg                       42      11.81
# Enalapril Mal_Tab 20mg                         649      10.92
# Enalapril Mal_Tab 10mg                         590      10.40
# Mirtazapine_Orodisper Tab 15mg                 776       9.82
# Telmisartan_Tab 20mg                           266       8.44
# Doxazosin Mesil_Tab 1mg                        597       8.40
# Digoxin_Tab 250mcg                             830       7.79
# Enalapril Mal_Tab 5mg                          273       7.60
# Duloxetine HCl_Cap G/R 40mg                    126       7.43
# Citalopram HCl_Oral Dps 40mg/ml S/F            195       7.36
# Lacidipine_Tab 4mg                             128       7.13
# Doxazosin Mesil_Tab 2mg                       1385       6.76
# Metoprolol Tart_Tab 50mg                        94       6.01
# Mirtazapine_Orodisper Tab 45mg                 713       5.80
# Pregabalin_Cap 225mg                           504       5.51
# Oxazepam_Tab 15mg                               42       5.06
# Glyceryl Trinit_Sub P/Spy 400mcg (200D)          8       3.79
# Lacidipine_Tab 2mg                             156       3.34
# Mirtazapine_Orodisper Tab 30mg                 360       1.44
#
# [181 rows x 2 columns]

# %%
## monthly impact of price concessions for nonCCG organisations
nonccg_ncso_thisyear.groupby('month').sum()
# Out:
#             quantity  add_cost
# month
# 2018-01-01    222494  12327.17
# 2018-02-01    526990  20018.37
# 2018-03-01    653831  23690.55
# 2018-04-01    988646  44416.92
# 2018-05-01    972794 870661.19
# 2018-06-01    795721 564720.51
# 2018-07-01    829977 626957.29
# 2018-08-01    820334 480744.40
# 2018-09-01    763815 738880.79
# 2018-10-01    841583 803794.83
# 2018-11-01   1001536 733813.97
# 2018-12-01    872304 712110.10

# %% [markdown]
# ### Impact on individual organisations

# %%
## assess impact on each organisation "PCT"
nonccg_ncso_orgs = nonccg_ncso_thisyear.groupby('pct').sum().sort_values(by = 'add_cost', ascending = False)

# %%
## import councils from NHS Digital ODS codes
df_councils = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\nonCCG Concessions\Lauth.csv')

# %%
## import "independent providers" from NHS Digital ODS codes
df_indprov = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\nonCCG Concessions\ephp.csv')
df_councils['pct'] = df_councils['pct'].astype('str')

# %%
## import hospitals from NHS Digital ODS codes
df_hosp = pd.read_csv(r'C:\Users\bmackenna\Documents\GitHub\nonCCG Concessions\etr.csv')

# %%
importmerge_orgnames_part1 = nonccg_ncso_orgs.reset_index().merge(df_councils[['pct','name']],  how = "outer", on = 'pct')

# %%
importmerge_orgnames_part2 = importmerge_orgnames_part1.merge(df_indprov[['pct','name']],  how="outer", on='pct', suffixes=("_council","_independent_provider"))

# %%
fullmerge = importmerge_orgnames_part2.merge(df_hosp[['pct','name']],  how="outer", on='pct')

# %%
fullmerge['purchaser_name'] = fullmerge['name_council'].fillna('') + fullmerge['name_independent_provider'].fillna('') + fullmerge['name'].fillna('')

# %%
purchaser_list = fullmerge.drop('name_council', axis=1) ####getting multiple errors when trying to drop all at once

# %%
purchaser_list1 = purchaser_list.drop('name', axis=1)

# %%
purchaser_list2 = purchaser_list1.drop('name_independent_provider', axis=1)
purchaser_list2[['purchaser_name', 'pct', 'add_cost']]
# Out:
#                                          purchaser_name  pct   add_cost
# 0                                    CHANGE, GROW, LIVE  NMS 2091871.32
# 1                                         TURNING POINT  NKI  582024.50
# 2                                             ADDACTION  NI3  226144.28
# 3                                    LEEDS CITY COUNCIL  212  181742.50
# 4     NORTHUMBERLAND, TYNE AND WEAR NHS FOUNDATION T...  RX4  174186.77
# 5                                 MIDDLESBROUGH COUNCIL  112  164438.04
# 6                      NEWCASTLE-UPON-TYNE CITY COUNCIL  107  124219.57
# 7                       SPECTRUM COMMUNITY HEALTH - CIC  NL1  122254.48
# 8                                     THE FORWARD TRUST  DG3  116849.06
# 9                      STOCKTON-ON-TEES BOROUGH COUNCIL  114  113859.05
# 10                                DURHAM COUNTY COUNCIL  116  113715.67
# 11                            WESTMINISTER DRUG PROJECT  ARG  102133.12
# 12                              SUNDERLAND CITY COUNCIL  110   95970.38
# 13           DERBYSHIRE HEALTHCARE NHS FOUNDATION TRUST  RXM   92836.56
# 14                                   DELPHI MEDICAL LTD  AKQ   90252.92
# 15                                   LIVEWELL SOUTHWEST  NR5   74896.55
# 16    ROTHERHAM DONCASTER AND SOUTH HUMBER NHS FOUND...  RXE   73648.59
# 17                      KINGSTON-UPON-HULL CITY COUNCIL  215   67434.86
# 18                                            HUMANKIND  AJ6   67408.74
# 19                                     KIRKLEES COUNCIL  211   66567.39
# 20                          STOKE-ON-TRENT CITY COUNCIL  414   66210.54
# 21                                            CRANSTOUN  DLA   61154.84
# 22               STOCKPORT METROPOLITAN BOROUGH COUNCIL  310   57318.39
# 23                           SWANSWELL CHARITABLE TRUST  AKV   53181.93
# 24                 WARRINGTON BOROUGH COUNCIL (UNITARY)  322   51624.80
# 25                    TOGETHER DRUG AND ALCOHOL SERVICE  DNK   50585.26
# 26                       NORTH YORKSHIRE COUNTY COUNCIL  218   44821.40
# 27                   WIGAN METROPOLITAN BOROUGH COUNCIL  313   44282.21
# 28    CHESHIRE AND WIRRAL PARTNERSHIP NHS FOUNDATION...  RXA   41878.93
# 29                              THE SOCIETY OF ST JAMES  DEC   38906.27
# ...                                                 ...  ...        ...
# 2212                     STOCKPORT NHS FOUNDATION TRUST  RWJ        nan
# 2213           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST  RWP        nan
# 2214  HERTFORDSHIRE PARTNERSHIP UNIVERSITY NHS FOUND...  RWR        nan
# 2215                        DEVON PARTNERSHIP NHS TRUST  RWV        nan
# 2216  WARRINGTON AND HALTON HOSPITALS NHS FOUNDATION...  RWW        nan
# 2217   CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST  RWY        nan
# 2218          NOTTINGHAM UNIVERSITY HOSPITALS NHS TRUST  RX1        nan
# 2219            SUSSEX PARTNERSHIP NHS FOUNDATION TRUST  RX2        nan
# 2220    TEES, ESK AND WEAR VALLEYS NHS FOUNDATION TRUST  RX3        nan
# 2221             NORTH WEST AMBULANCE SERVICE NHS TRUST  RX7        nan
# 2222              YORKSHIRE AMBULANCE SERVICE NHS TRUST  RX8        nan
# 2223          EAST MIDLANDS AMBULANCE SERVICE NHS TRUST  RX9        nan
# 2224                  MID YORKSHIRE HOSPITALS NHS TRUST  RXF        nan
# 2225  BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST  RXL        nan
# 2226  LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION T...  RXN        nan
# 2227  COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST  RXP        nan
# 2228                EAST LANCASHIRE HOSPITALS NHS TRUST  RXR        nan
# 2229  BIRMINGHAM AND SOLIHULL MENTAL HEALTH NHS FOUN...  RXT        nan
# 2230  GREATER MANCHESTER MENTAL HEALTH NHS FOUNDATIO...  RXV        nan
# 2231          SHREWSBURY AND TELFORD HOSPITAL NHS TRUST  RXW        nan
# 2232  SURREY AND BORDERS PARTNERSHIP NHS FOUNDATION ...  RXX        nan
# 2233  KENT AND MEDWAY NHS AND SOCIAL CARE PARTNERSHI...  RXY        nan
# 2234  HOUNSLOW AND RICHMOND COMMUNITY HEALTHCARE NHS...  RY9        nan
# 2235  WEST MIDLANDS AMBULANCE SERVICE NHS FOUNDATION...  RYA        nan
# 2236        EAST OF ENGLAND AMBULANCE SERVICE NHS TRUST  RYC        nan
# 2237  SOUTH EAST COAST AMBULANCE SERVICE NHS FOUNDAT...  RYD        nan
# 2238  SOUTH CENTRAL AMBULANCE SERVICE NHS FOUNDATION...  RYE        nan
# 2239      WESTERN SUSSEX HOSPITALS NHS FOUNDATION TRUST  RYR        nan
# 2240                      PUBLIC HEALTH WALES NHS TRUST  RYT        nan
# 2241        CAMBRIDGESHIRE COMMUNITY SERVICES NHS TRUST  RYV        nan
#
# [2242 rows x 3 columns]

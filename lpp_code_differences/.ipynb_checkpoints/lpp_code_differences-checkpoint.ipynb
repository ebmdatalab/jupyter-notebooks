# %%
#import libraries required for analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline

# %% [markdown]
# ### Data from epact2 tags

# %%
projectid = "ebmdatalab"
#obtain practice level data for low value medicines from ePACT2 tags
lpp_epact2_df = pd.read_gbq("""
SELECT
  epact2.lpp_code,
  practice,
  pct,
  SUM(items) AS items,
  SUM(actual_cost) AS actual_cost
FROM
  `hscic.normalised_prescribing_standard` AS rx
JOIN
  `richard.lpp_epact2` AS epact2
ON
  epact2.bnf_code=rx.bnf_code
WHERE
  rx.month BETWEEN '2018-01-01 00:00:00'
  AND '2018-03-01 00:00:00'
GROUP BY
  epact2.lpp_code,
  practice,
  pct
""", projectid, dialect='standard')
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=495642085510-k0tmvj2m941jhre2nbqka17vqpjfddtd.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=5KKd5X1q8EhPpkUx1w1plxoApFRFEN&access_type=offline&prompt=consent
# Enter the authorization code: 4/AADcnihNxH63ANOYn6Ekumn7Xh1WwtK3UCtf8DClqexcE6tVZNMBQWM
# Requesting query... ok.
# Job ID: job_geLRR9Xm4utiD2YVz7aacf1lA_o0
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
#   Got page: 1; 100% done. Elapsed 8.36 s.
# Got 60307 rows.
#
# Total time taken 10.79 s.
# Finished at 2018-07-10 11:42:25.

# %%
lpp_epact2_df.head(10)
# Out:
#   lpp_code practice  pct  items  actual_cost
# 0       04   A83005  00C      9   1755.99810
# 1       09   A83005  00C      2    939.64363
# 2       02   A83005  00C     57    124.60941
# 3       12   A83005  00C     26    385.50497
# 4       15   A83005  00C     34    135.20843
# 5       16   A83005  00C     14    969.16921
# 6       08   A83005  00C     37   2999.55726
# 7       17   A83006  00C      1     12.04016
# 8       08   A83006  00C     14   1141.34138
# 9       11   A83006  00C      3    237.73484

# %% [markdown]
# ### Data from OpenPrescribing tags

# %%
#obtain practice level data for low value medicines missing from OP tags
lpp_op_df = pd.read_gbq("""
SELECT
  op.lpp_code,
  practice,
  pct,
  SUM(items) AS items,
  SUM(actual_cost) AS actual_cost
FROM
  `hscic.normalised_prescribing_standard` AS rx
JOIN
  `richard.lpp_op_bnf_vw` AS op
ON
  op.bnf_code=rx.bnf_code
JOIN
  richard.lpp_codes as lpp
ON
  op.lpp_code=lpp.lpp_code
WHERE
  rx.month BETWEEN '2018-01-01 00:00:00'
  AND '2018-03-01 00:00:00'
GROUP BY
  op.lpp_code,
  practice,
  pct
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_7NXImLkbZG6bI7DWNtJMNswz874i
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 61905 rows.
#
# Total time taken 8.17 s.
# Finished at 2018-07-10 11:42:55.

# %%
#obtain lpp_areas
lpp_area_df = pd.read_gbq("""
SELECT * from richard.lpp_codes
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_ndULIq9eJUvBygRsQCXhRzMQbzQT
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 18 rows.
#
# Total time taken 1.13 s.
# Finished at 2018-07-10 11:43:18.

# %%
lpp_op_df.head(10)
# Out:
#   lpp_code practice  pct  items  actual_cost
# 0       12   A83005  00C     26    385.50497
# 1       15   A83005  00C     34    135.20843
# 2       16   A83005  00C     14    969.16921
# 3       02   A83005  00C     57    124.60941
# 4       04   A83005  00C      9   1755.99810
# 5       10   A83005  00C      2     35.04789
# 6       09   A83005  00C      2    939.64363
# 7       08   A83005  00C     37   2999.55726
# 8       17   A83006  00C      1     12.04016
# 9       08   A83006  00C     14   1141.34138

# %% [markdown]
# ### LPP codes

# %%
lpp_area_df.head(20)
# Out:
#    lpp_code                                           lpp_name
# 0        01                                        Co-proxamol
# 1        02                                          Dosulepin
# 2        03                        Prolonged-release Doxazosin
# 3        04                         Immediate Release Fentanyl
# 4        05                        Glucosamine and Chondroitin
# 5        06                                  Herbal Treatments
# 6        07                                         Homeopathy
# 7        08                                 Lidocaine Plasters
# 8        09  Liothyronine (including Armour Thyroid and lio...
# 9        10                            Lutein and Antioxidants
# 10       11                       Omega-3 Fatty Acid Compounds
# 11       12         Oxycodone and Naloxone Combination Product
# 12       13       Paracetamol and Tramadol Combination Product
# 13       14                               Perindopril Arginine
# 14       15            Rubefacients (excluding topical NSAIDs)
# 15       16                               Once Daily Tadalafil
# 16       17  Travel Vaccines (vaccines administered exclusi...
# 17       18                                       Trimipramine

# %% [markdown]
# So, how do we merge the two dataframes (`lpp_op_df` and `lpp_epact2_df`) and `lpp_area.df` to show a single dataframe with the `lpp_code`, `lpp_name`, `practice` and `pct`, and having columns for the `lpp_op_df` and `lpp_epact2_df` items and actual_cost, without excluding any practices on areas (e.g. showing nulls)?

# %%
merged = lpp_op_df.merge(lpp_epact2_df, on=['lpp_code', 'practice'], how='outer', suffixes=['_op', '_epact'])

# %%
merged.actual_cost_epact = merged.actual_cost_epact.apply(lambda x: np.round(x, 4))
merged.actual_cost_op = merged.actual_cost_op.apply(lambda x: np.round(x, 4))

# %%
not_matching = merged[merged.actual_cost_epact != merged.actual_cost_op]

# %%
not_matching.head()
# Out:
#    lpp_code practice pct_op  items_op  actual_cost_op pct_epact  items_epact  \
# 5        10   A83005    00C       2.0         35.0479       NaN          NaN
# 16       10   A83010    00C       1.0         18.4528       NaN          NaN
# 21       15   A83010    00C      13.0         96.9467       00C         12.0
# 40       10   A83031    00C       3.0         52.5839       NaN          NaN
# 42       05   A83031    00C       1.0          1.2892       NaN          NaN
#
#     actual_cost_epact
# 5                 NaN
# 16                NaN
# 21            94.2705
# 40                NaN
# 42                NaN

# %%
merged.head()
# Out:
#   lpp_code practice pct_op  items_op  actual_cost_op pct_epact  items_epact  \
# 0       12   A83005    00C      26.0        385.5050       00C         26.0
# 1       15   A83005    00C      34.0        135.2084       00C         34.0
# 2       16   A83005    00C      14.0        969.1692       00C         14.0
# 3       02   A83005    00C      57.0        124.6094       00C         57.0
# 4       04   A83005    00C       9.0       1755.9981       00C          9.0
#
#    actual_cost_epact
# 0           385.5050
# 1           135.2084
# 2           969.1692
# 3           124.6094
# 4          1755.9981

# %%
merged_by_lpp=merged.groupby(['pct_op'])['items_op','items_epact'].sum()

# %%
merged_by_lpp.head(20)
# Out:
#         items_op  items_epact
# pct_op
# 00C       1417.0       1406.0
# 00D       3661.0       3611.0
# 00J       3592.0       3394.0
# 00K       3428.0       3420.0
# 00L       3845.0       3892.0
# 00M       4066.0       4092.0
# 00N       1735.0       1708.0
# 00P       4623.0       4549.0
# 00Q       3175.0       3154.0
# 00R       3968.0       3911.0
# 00T       7189.0       7191.0
# 00V       3006.0       2996.0
# 00X       2453.0       2446.0
# 00Y       6084.0       6025.0
# 01A       8765.0       8732.0
# 01C       2614.0       2596.0
# 01D       4786.0       4729.0
# 01E       3745.0       3703.0
# 01F       2893.0       2844.0
# 01G       3732.0       3692.0

# %%
ccg_data_df=merged_by_lpp.pct_change(axis=1)
ccg_data_df=ccg_data_df.drop(['items_op'], axis=1)
ccg_data_df.rename(index=str, columns={"items_epact": "percent_difference"})
# Out:
#         percent_difference
# pct_op
# 00C              -0.007763
# 00D              -0.013657
# 00J              -0.055122
# 00K              -0.002334
# 00L               0.012224
# 00M               0.006394
# 00N              -0.015562
# 00P              -0.016007
# 00Q              -0.006614
# 00R              -0.014365
# 00T               0.000278
# 00V              -0.003327
# 00X              -0.002854
# 00Y              -0.009698
# 01A              -0.003765
# 01C              -0.006886
# 01D              -0.011910
# 01E              -0.011215
# 01F              -0.016937
# 01G              -0.010718
# 01H              -0.044561
# 01J              -0.191228
# 01K              -0.012863
# 01R              -0.005752
# 01T              -0.014467
# 01V              -0.009312
# 01W              -0.027710
# 01X              -0.256570
# 01Y              -0.020851
# 02A              -0.010213
# ...                    ...
# RHA               0.000000
# RJ1               0.000000
# RJ7               0.000000
# RJ8               0.000000
# RL4               0.000000
# RLY               0.000000
# RM1               0.000000
# RNA               0.000000
# RNU               0.000000
# RRF              -0.750000
# RTQ               0.000000
# RTR               0.000000
# RTV               0.000000
# RVW               0.000000
# RWE               0.000000
# RWX               0.000000
# RXA               0.000000
# RXH               0.000000
# RXK               0.000000
# RY1               0.000000
# RY2              -0.105263
# RY3               0.000000
# RY4               0.000000
# RY5               0.000000
# RY6               0.000000
# RY7               0.000000
# RY8               0.000000
# RYF               0.000000
# RYG               0.000000
# RYW               0.000000
#
# [257 rows x 1 columns]

# %%
ccg_data_df.head()
# Out:
#         items_epact
# pct_op
# 00C       -0.007763
# 00D       -0.013657
# 00J       -0.055122
# 00K       -0.002334
# 00L        0.012224

# %%
import matplotlib.gridspec as gridspec
# join to geographical data
map_data = ccg_data_df.reset_index()
names = pd.read_csv('https://raw.githubusercontent.com/ebmdatalab/jupyter-notebooks/master/antibiotics/ccg_for_map.csv')
map_data = map_data.merge(names[['code','name']],left_on="pct_op",right_on="code")
map_data['name'] = map_data['name'].str.upper()
map_data['name'] = map_data["name"].str.replace("&","AND")
map_data = map_data.set_index('name')

# %%
import geopandas as gpd
from matplotlib import verbose
# from our API https://openprescribing.net/api/1.0/org_location/?org_type=ccg
ccgs = gpd.read_file('ccgs.json').set_index('name')

ccgs = ccgs[~ccgs['geometry'].isnull()]  # remove ones without geometry - these are federations rather than individual CCGs
gdf= ccgs.join(map_data)

# set sort order of measures manually, and add grid refs to position each subplot:
s_map = [(0,'percent_difference',0,0)]

# set common value limits for colour scale
vmin, vmax = 0, 100

fig = plt.figure(figsize=(16,6))
gs = gridspec.GridSpec(1,3, width_ratios=[4,4,5])  # grid layout for subplots

for i in s_map:
    ax = plt.subplot(gs[i[2], i[3]])  # position of subplot in grid using coordinates listed in s
    gdf.plot(ax=ax,column=i[1],  edgecolor='black', linewidth=0.1, legend=False, cmap='coolwarm',vmin=vmin, vmax=vmax)
    ax.set_aspect(1.63)
    ax.set_title('After amended PHE guidance \n(October 2014-March 2015)', size=16)
    plt.axis('off')

plt.subplots_adjust(wspace = 0.05,hspace = 0.05)
#plt.savefig('Figure 3.png', format='png', dpi=300,bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'percent_difference'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-ec98c3427b22> in <module>()
#      18 for i in s_map:
#      19     ax = plt.subplot(gs[i[2], i[3]])  # position of subplot in grid using coordinates listed in s
# ---> 20     gdf.plot(ax=ax,column=i[1],  edgecolor='black', linewidth=0.1, legend=False, cmap='coolwarm',vmin=vmin, vmax=vmax)
#      21     ax.set_aspect(1.63)
#      22     ax.set_title('After amended PHE guidance \n(October 2014-March 2015)', size=16)
#
# C:\Users\racro\Anaconda3\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     467     def plot(self, *args, **kwargs):
#     468
# --> 469         return plot_dataframe(self, *args, **kwargs)
#     470
#     471     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Users\racro\Anaconda3\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, figsize, **style_kwds)
#     397                            figsize=figsize, **style_kwds)
#     398
# --> 399     if df[column].dtype is np.dtype('O'):
#     400         categorical = True
#     401
#
# C:\Users\racro\Anaconda3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     396         GeoDataFrame.
#     397         """
# --> 398         result = super(GeoDataFrame, self).__getitem__(key)
#     399         geo_col = self._geometry_column_name
#     400         if isinstance(key, string_types) and key == geo_col:
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'percent_difference'

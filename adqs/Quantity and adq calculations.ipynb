# %%
import pandas as pd

# Filter out warnings per https://stackoverflow.com/a/40846742/559140
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

# %%
# CSV created with output of this view: https://gist.github.com/sebbacon/c495b58803f85ce70dd26a311db7b432
dmd = pd.read_csv('products.csv')
dmd.iloc[0]
# Out:
# bnf_code                           010101000BBAJA0
# name                           Indigestion mixture
# vpid                             11772211000001100
# form                               Oral suspension
# form_indicator                            Discrete
# form_size                                        5
# form_units                                      ml
# unit_of_measure                           spoonful
# numerator                                       35
# numerator_unit_of_measure                       mg
# denominator                                      1
# denominator_unit_of_measure                     ml
# ingredient_count                                 3
# Name: 0, dtype: object

# %%
squs = pd.read_csv('squs.csv')  # These were generated by running pca_quantity_fetcher.py
dmd = dmd.merge(squs, on='bnf_code')

# %%
# Compute the quantity_denominator. This prefers SQUs from data but where this is missing, uses a heuristic to guess.
import adq_lib
dmd['quantity_denominator'] = dmd.apply(adq_lib.compute_quantity_units, axis=1)

# %%
# Import ADQs (which we got from an FOI) and normalise their units to grammes, ml, units, or unit doses
adqs = pd.read_csv('adqs_2017_06_01.csv')
adqs.columns = ['bnf_code', 'bnf_name', 'adq_value', 'adq_denominator']
adqs = adqs[~pd.isnull(adqs['adq_value'])]
adqs['dose_multiplier'] = adqs['bnf_name'].apply(adq_lib.dose_from_name)
import functools
normalise_adq = functools.partial(adq_lib.normalise, number_name='adq_value', unit_name='adq_denominator')
adqs = adqs.apply(normalise_adq, axis=1)

# %%
# Normalise numerators and denominators from DMD in the same way
normalise_numerator = functools.partial(adq_lib.normalise, number_name='numerator', unit_name='numerator_unit_of_measure')
dmd = dmd.apply(normalise_numerator, axis=1)
normalise_denominator = functools.partial(adq_lib.normalise, number_name='denominator', unit_name='denominator_unit_of_measure')
dmd = dmd.apply(normalise_denominator, axis=1)
#

# %%
merged = dmd.merge(adqs, on='bnf_code')
merged
# Out:
#              bnf_code                                               name  \
# 0     0101010J0AAAAAA                Boots Magnesium trisilicate mixture
# 1     0101010J0AAAAAA              Magnesium trisilicate oral suspension
# 2     0101010L0BBABAA                            Asilone oral suspension
# 3     0101010L0BBABAA                            Asilone oral suspension
# 4     0101010L0BBABAA                            Asilone oral suspension
# 5     0101010L0BBAEAK                             Asilone Antacid liquid
# 6     0101010L0BBAEAK                             Asilone Antacid liquid
# 7     0101010L0BBAEAK                             Asilone Antacid liquid
# 8     0101010L0BEAAAI                        Maalox Plus oral suspension
# 9     0101010L0BEAAAI                        Maalox Plus oral suspension
# 10    0101010L0BEAAAI                        Maalox Plus oral suspension
# 11    0101010Q0AAAGAG  Magnesium hydroxide 7.45-8.35% oral suspension BP
# 12    0101010Q0BDACAA  Phillips' Milk of Magnesia 415mg/5ml oral susp...
# 13    0102000A0AAAAAA                             Alverine 60mg capsules
# 14    0102000A0AAABAB                            Alverine 120mg capsules
# 15    0102000A0BBAAAA                            Spasmonal 60mg capsules
# 16    0102000A0BBABAB                     Spasmonal Forte 120mg capsules
# 17    0102000A0BDAAAA                             Audmonal 60mg capsules
# 18    0102000A0BDABAB                      Audmonal Forte 120mg capsules
# 15          1.0    capsule         capsule    0.06000
# 16          1.0    capsule         capsule    0.12000
# 17          1.0    capsule         capsule    0.06000
# 18          1.0    capsule         capsule    0.12000
# 19          1.0     tablet          tablet    0.00060
# 20          NaN        NaN             NaN    0.00010
# 21          NaN        NaN             NaN    0.00004
# 22          NaN        NaN             NaN    0.00012
# 23          NaN        NaN             NaN    0.00006
# 24          NaN        NaN             NaN    0.00006
# 25          NaN        NaN             NaN    0.00001
# 26          NaN        NaN             NaN    0.00005
# 27          NaN        NaN             NaN    0.00005
# 28          NaN        NaN             NaN    0.00010
# 29          5.0         ml        spoonful    0.00200
# ...         ...        ...             ...        ...
# 5987        1.0     tablet          tablet    0.25000
# 5988        1.0    capsule         capsule    0.01000
# 5989        1.0    capsule         capsule    0.02000
# 5990        1.0     tablet          tablet    0.01000
# 5991        1.0     tablet          tablet    0.02000
# 5992        1.0    capsule         capsule    0.01000
# 5993        1.0    capsule         capsule    0.02000
# 5994        1.0     tablet          tablet    0.02000
# 5995        1.0     tablet          tablet    0.02000
# 5996        1.0     tablet          tablet    0.10000
# 5997        1.0     tablet          tablet    0.20000
# 5998        1.0     tablet          tablet    0.20000
# 5999        1.0     tablet          tablet    0.30000
# 6000        1.0     tablet          tablet    0.30000
# 6001        1.0    capsule         capsule    0.30000
# 6002        1.0     tablet          tablet    0.50000
# 6003        1.0     tablet          tablet    0.50000
# 6004        1.0       vial            vial    0.10000
# 6005        NaN        NaN             NaN    0.00500
# 6006        NaN        NaN             NaN    0.00500
# 6007        1.0       dose            dose    0.00005
# 6008        1.0  unit dose       unit dose    0.00040
# 6009        1.0       dose            dose    0.00005
# 6010        1.0       dose            dose    0.00005
# 6011        1.0       dose            dose    0.00005
# 6012        1.0       dose            dose    0.00005
# 6013        1.0       dose            dose    0.00005
# 6014        1.0       dose            dose    0.00005
# 6015        1.0       dose            dose    0.00005
# 6016        1.0     tablet          tablet    0.02000
#
#      numerator_unit_of_measure  denominator denominator_unit_of_measure  \
# 0                            g          1.0                          ml
# 1                            g          1.0                          ml
# 2                            g          1.0                          ml
# 3                            g          1.0                          ml
# 4                            g          1.0                          ml
# 5                            g          1.0                          ml
# 6                            g          1.0                          ml
# 7                            g          1.0                          ml
# 8                            g          1.0                          ml
# 9                            g          1.0                          ml
# 10                           g          1.0                          ml
# 11                           g          1.0                          ml
# 12                           g          1.0                          ml
# 13                           g          NaN                         nan
# 14                           g          NaN                         nan
# 15                           g          NaN                         nan
# 16                           g          NaN                         nan
# 17                           g          NaN                         nan
# 18                           g          NaN                         nan
# 19                           g          NaN                         nan
# 20                           g          1.0                          ml
# 21                           g          1.0                          ml
# 22                           g          1.0                          ml
# 23                           g          1.0                          ml
# 24                           g          1.0                          ml
# 25                           g          1.0                          ml
# 26                           g          1.0                          ml
# 27                           g          1.0                          ml
# 28                           g          1.0                          ml
# 29                           g          1.0                          ml
# ...                        ...          ...                         ...
# 5987                         g          NaN                         nan
# 5988                         g          NaN                         nan
# 5989                         g          NaN                         nan
# 5990                         g          NaN                         nan
# 5991                         g          NaN                         nan
# 5992                         g          NaN                         nan
# 5993                         g          NaN                         nan
# 5994                         g          NaN                         nan
# 5995                         g          NaN                         nan
# 5996                         g          NaN                         nan
# 5997                         g          NaN                         nan
# 5998                         g          NaN                         nan
# 5999                         g          NaN                         nan
# 6000                         g          NaN                         nan
# 6001                         g          NaN                         nan
# 6002                         g          NaN                         nan
# 6003                         g          NaN                         nan
# 6004                         g          NaN                         nan
# 6005                         g          1.0                          ml
# 6006                         g          1.0                          ml
# 6007                         g          1.0                        dose
# 6008                         g          NaN                         nan
# 6009                         g          1.0                        dose
# 6010                         g          1.0                        dose
# 6011                         g          1.0                        dose
# 6012                         g          1.0                        dose
# 6013                         g          1.0                        dose
# 6014                         g          1.0                        dose
# 6015                         g          1.0                        dose
# 6016                         g          NaN                         nan
#
#       ingredient_count   squ quantity_denominator  \
# 0                  3.0    ml                   ml
# 1                  3.0    ml                   ml
# 2                  3.0    ml                   ml
# 3                  3.0    ml                   ml
# 4                  3.0    ml                   ml
# 5                  3.0    ml                   ml
# 6                  3.0    ml                   ml
# 7                  3.0    ml                   ml
# 8                  3.0    ml                   ml
# 9                  3.0    ml                   ml
# 10                 3.0    ml                   ml
# 11                 1.0    ml                   ml
# 12                 1.0    ml                   ml
# 13                 1.0  unit                 unit
# 14                 1.0  unit                 unit
# 15                 1.0  unit                 unit
# 16                 1.0  unit                 unit
# 17                 1.0  unit                 unit
# 18                 1.0  unit                 unit
# 19                 1.0  unit                 unit
# 20                 1.0    ml                   ml
# 21                 1.0    ml                   ml
# 22                 1.0    ml                   ml
# 23                 1.0    ml                   ml
# 24                 1.0    ml                   ml
# 25                 1.0    ml                   ml
# 26                 1.0    ml                   ml
# 27                 1.0    ml                   ml
# 28                 1.0    ml                   ml
# 29                 1.0    ml                   ml
# ...                ...   ...                  ...
# 5987               1.0  unit                 unit
# 5988               1.0  unit                 unit
# 5989               1.0  unit                 unit
# 5990               1.0  unit                 unit
# 5991               1.0  unit                 unit
# 5992               1.0  unit                 unit
# 5993               1.0  unit                 unit
# 5994               1.0  unit                 unit
# 5995               1.0  unit                 unit
# 5996               1.0  unit                 unit
# 5997               1.0  unit                 unit
# 5998               1.0  unit                 unit
# 5999               1.0  unit                 unit
# 6000               1.0  unit                 unit
# 6001               1.0  unit                 unit
# 6002               1.0  unit                 unit
# 6003               1.0  unit                 unit
# 6004               1.0  unit                 unit
# 6005               1.0    ml                   ml
# 6006               1.0    ml                   ml
# 6007               1.0  unit                 unit
# 6008               1.0  unit                 unit
# 6009               1.0  unit                 unit
# 6010               1.0  unit                 unit
# 6011               1.0  unit                 unit
# 6012               1.0  unit                 unit
# 6013               1.0  unit                 unit
# 6014               1.0  unit                 unit
# 6015               1.0  unit                 unit
# 6016               1.0  unit                 unit
#
#                                       bnf_name  adq_value adq_denominator  \
# 0                               Mag Trisil_Mix   30.00000              ml
# 1                               Mag Trisil_Mix   30.00000              ml
# 2                             Asilone_Susp S/F   30.00000
# 3                             Asilone_Susp S/F   30.00000
# 4                             Asilone_Susp S/F   30.00000
# 5                      Asilone Antacid_Liq S/F   30.00000
# 6                      Asilone Antacid_Liq S/F   30.00000
# 7                      Asilone Antacid_Liq S/F   30.00000
# 8                         Maalox Plus_Susp S/F   30.00000
# 9                         Maalox Plus_Susp S/F   30.00000
# 10                        Maalox Plus_Susp S/F   30.00000
# 11          Mag Hydrox_Oral Susp 7.45-8.35% BP   30.00000              ml
# 12        Phillips Milk Of Magnesia_Liq (Mint)   30.00000              ml
# 13                       Alverine Cit_Cap 60mg    0.18000               g
# 14                      Alverine Cit_Cap 120mg    0.18000               g
# 15                          Spasmonal_Cap 60mg    0.18000               g
# 16                     Spasmonal Fte_Cap 120mg    0.18000               g
# 17                           Audmonal_Cap 60mg    0.18000               g
# 18                    Audmonal_Forte Cap 120mg    0.18000               g
# 19                       Atrop Sulf_Tab 600mcg    0.00120               g
# 20             Atrop Sulf_Oral Susp 500mcg/5ml    0.00120               g
# 21              Atrop Sulf_Liq Spec 200mcg/5ml    0.00120               g
# 22              Atrop Sulf_Liq Spec 600mcg/5ml    0.00120               g
# 23              Atrop Sulf_Liq Spec 300mcg/5ml    0.00120               g
# 24              Atrop Sulf_Liq Spec 300mcg/5ml    0.00120               g
# 25               Atrop Sulf_Liq Spec 50mcg/5ml    0.00120               g
# 26              Atrop Sulf_Liq Spec 250mcg/5ml    0.00120               g
# 27              Atrop Sulf_Liq Spec 250mcg/5ml    0.00120               g
# 28        Atrop Sulf_Oral Soln 500mcg/5ml (DT)    0.00120               g
# 29        Dicycloverine HCl_Oral Soln 10mg/5ml    0.03000               g
# ...                                        ...        ...             ...
# 5987                 Stirlescent_Tab Eff 250mg    0.75000               g
# 5988                        Piroxicam_Cap 10mg    0.02000               g
# 5989                        Piroxicam_Cap 20mg    0.02000               g
# 5990                 Piroxicam_Tab Disper 10mg    0.02000               g
# 5991                 Piroxicam_Tab Disper 20mg    0.02000               g
# 5992                          Feldene_Cap 10mg    0.02000               g
# 5993                       Feldene 20_Cap 20mg    0.02000               g
# 5994                     Feldene_Tab Melt 20mg    0.02000               g
# 5995                         Brexidol_Tab 20mg    0.02000               g
# 5996                        Sulindac_Tab 100mg    0.40000               g
# 5997                        Sulindac_Tab 200mg    0.40000               g
# 5998                        Clinoril_Tab 200mg    0.40000               g
# 5999                Tiaprofenic Acid_Tab 300mg    0.60000               g
# 6000                      Surgam 300_Tab 300mg    0.60000               g
# 6001                       Surgam SA_Cap 300mg    0.60000               g
# 6002                      Nabumetone_Tab 500mg    1.00000               g
# 6003                         Relifex_Tab 500mg    1.00000               g
# 6004                     Remicade_Inf 100mg Vl    0.00375               g
# 6005               Levofloxacin_Eye Dps 5mg/ml    0.25000               g
# 6006                   Oftaquix_Eye Dps 5mg/ml    0.25000               g
# 6007    Fluticasone Prop_Nsl Spy 50mcg (150 D)    0.00200               g
# 6008         Flixonase_Aq Nasule Dps 400mcg Ud    0.00200               g
# 6009        Flixonase_Aq Nsl Spy 50mcg (150 D)    0.00200               g
# 6010          Nasofan_Aq Nsl Spy 50mcg (150 D)    0.00200               g
# 6011   Nasofan_Allergy Aq Nsl Spy 50mcg (60 D)    0.00200               g
# 6012     Pirinase_Hayfever Nsl Spy 0.05% (60D)    0.00200               g
# 6013  Pirinase_H/FvrRelAdult NslSpy 0.05%(60D)    0.00200               g
# 6014     Mometasone Fur_Aq N/Spy 50mcg (140 D)    0.00040               g
# 6015            Nasonex_Aq N/Spy 50mcg (140 D)    0.00040               g
# 6016                        Periostat_Tab 20mg    0.10000               g
#
#       dose_multiplier
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# 5                 1.0
# 6                 1.0
# 7                 1.0
# 8                 1.0
# 9                 1.0
# 10                1.0
# 11                1.0
# 12                1.0
# 13                1.0
# 14                1.0
# 15                1.0
# 16                1.0
# 17                1.0
# 18                1.0
# 19                1.0
# 20                1.0
# 21                1.0
# 22                1.0
# 23                1.0
# 24                1.0
# 25                1.0
# 26                1.0
# 27                1.0
# 28                1.0
# 29                1.0
# ...               ...
# 5987              1.0
# 5988              1.0
# 5989              1.0
# 5990              1.0
# 5991              1.0
# 5992              1.0
# 5993              1.0
# 5994              1.0
# 5995              1.0
# 5996              1.0
# 5997              1.0
# 5998              1.0
# 5999              1.0
# 6000              1.0
# 6001              1.0
# 6002              1.0
# 6003              1.0
# 6004              1.0
# 6005              1.0
# 6006              1.0
# 6007            150.0
# 6008              1.0
# 6009            150.0
# 6010            150.0
# 6011             60.0
# 6012             60.0
# 6013             60.0
# 6014            140.0
# 6015            140.0
# 6016              1.0
#
# [6017 rows x 19 columns]

# %% [markdown]
# # Now check

# %%
sql = """
WITH
  numbered AS (
  SELECT
    Practice_Code,
    BNF_Code,
    BNF_Description,
    Items,
    Quantity,
    ADQ_Usage,
    ROW_NUMBER() OVER (PARTITION BY BNF_Code ORDER BY BNF_Code) AS rownum
  FROM
    tmp_eu.raw_prescribing_data_2018_05
  WHERE
    ADQ_Usage > 0 )
SELECT
  Practice_Code,
  BNF_Code,
  BNF_Description,
  Items,
  Quantity,
  ADQ_Usage
FROM
  numbered
WHERE
  rownum = 1
"""
data_with_adqs = pd.io.gbq.read_gbq(sql, 'ebmdatalab', dialect='standard',verbose=False)
# Out:
# /home/seb/.local/share/virtualenvs/jupyter/local/lib/python3.6/site-packages/pandas_gbq/gbq.py:556: FutureWarning: verbose is deprecated and will be removed in a future version. Set logging level in order to vary verbosity
#   "verbosity", FutureWarning, stacklevel=1)

# %%
merged['adq_per_quantity'] = merged.apply(adq_lib.adq_per_quantity, axis=1)

# %%
# Do QA check against NHS Digital data
df = data_with_adqs.merge(merged, left_on="BNF_Code", right_on="bnf_code")
df['computed_adq'] = df.apply(lambda x: (x.Quantity * x.Items * x.adq_per_quantity), axis=1)

# %%
df2 = df[df['ADQ_Usage'].round(1) != df['computed_adq'].round(1)].set_index("BNF_Code")
print("There are approximately {}/{} ADQs that are possibly incorrect".format(len(df2), len(df)))
print("Legit reasons include ADQs having been changed since the last spreadsheet was FOIed, DMD data wrong or missing.  See notes.md for some examples")
# Out:
# There are approximately 103/3818 ADQs that are possibly incorrect
# Legit reasons include ADQs having been changed since the last spreadsheet was FOIed, DMD data wrong or missing.  See notes.md for some examples

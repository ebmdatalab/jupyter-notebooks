# %% [markdown]
# ### Obtaining data from BigQuery

# %%
#import libraries required for analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline

# %%
projectid = "ebmdatalab"
#obtain long term trends data for trimethoprim and nitrofurantoin
lt_overall_df = pd.read_gbq("""
SELECT
  year,
  SUM(CASE
      WHEN chemical ='Trimethoprim' THEN items
      ELSE 0 END) AS trimethoprim_items,
  SUM(CASE
      WHEN chemical ='Nitrofurantoin' THEN items
      ELSE 0 END) AS nitrofurantoin_items  
FROM
  `ebmdatalab.hscic.prescribing_pca_1998_2016_full_v2`
WHERE
  chemical LIKE 'Trimethoprim'
  OR chemical LIKE 'Nitrofurantoin'
GROUP BY
  year,
  chemical
  """, projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_p_Pei34Wn5LUQssBpEcu5so7VRuJ
# Query running...
# Query done.
# Processed: 7.9 MB
# Standard price: $0.00 USD
#
# Retrieving results...
# Got 57 rows.
#
# Total time taken 2.68 s.
# Finished at 2018-03-06 16:06:36.

# %%
projectid = "ebmdatalab"
#obtain overall data for all CCG prescribing for trimethoprim
overall_df = pd.read_gbq("""
SELECT
  FORMAT_TIMESTAMP("%B %Y", trimethoprim.month) as month_string,
  trimethoprim.month as period,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
      ELSE 0 END) AS trimethoprim_items,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501130R0' THEN items
      ELSE 0 END) AS nitrofurantoin_items
  SUM(CASE
      WHEN trimethoprim.bnf_code like '0501080W0%AE' THEN quantity)
      ELSE 0 END) AS trimethoprim_200_quantity
FROM
ebmdatalab.richard.trimethoprim_data AS trimethoprim
INNER JOIN
  ebmdatalab.hscic.ccgs AS ccg
ON
  trimethoprim.pct=ccg.code
WHERE
ccg.org_type = 'CCG'
and   trimethoprim.month >='2011-01-01 00:00:00'
GROUP BY
  period, month_string
ORDER BY
  period
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_K4eqI4RdjouzIzYIYfeb_-HnJF9q
# Query running...
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# C:\Users\racro\Anaconda3\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, **kwargs)
#     541                     projectId=job_reference['projectId'],
# --> 542                     jobId=job_id).execute()
#     543             except HttpError as ex:
#
# C:\Users\racro\Anaconda3\lib\site-packages\oauth2client\util.py in positional_wrapper(*args, **kwargs)
#     134                     logger.warning(message)
# --> 135             return wrapped(*args, **kwargs)
#     136         return positional_wrapper
#
# C:\Users\racro\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     839     if resp.status >= 300:
# --> 840       raise HttpError(resp, content, uri=self.uri)
#     841     return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://www.googleapis.com/bigquery/v2/projects/ebmdatalab/queries/job_K4eqI4RdjouzIzYIYfeb_-HnJF9q?alt=json returned "Syntax error: Unexpected identifier "SUM" at [11:3]">
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-65-cc25aa4ab55c> in <module>()
#      27 ORDER BY
#      28   period
# ---> 29 """, projectid, dialect='standard')
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\io\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, verbose, private_key, dialect, **kwargs)
#      98         private_key=private_key,
#      99         dialect=dialect,
# --> 100         **kwargs)
#     101
#     102
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas_gbq\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, verbose, private_key, auth_local_webserver, dialect, **kwargs)
#     905         project_id, reauth=reauth, verbose=verbose, private_key=private_key,
#     906         dialect=dialect, auth_local_webserver=auth_local_webserver)
# --> 907     schema, pages = connector.run_query(query, **kwargs)
#     908     dataframe_list = []
#     909     while len(pages) > 0:
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, **kwargs)
#     542                     jobId=job_id).execute()
#     543             except HttpError as ex:
# --> 544                 self.process_http_error(ex)
#     545
#     546         if self.verbose:
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas_gbq\gbq.py in process_http_error(ex)
#     452
#     453                 raise GenericGBQException(
# --> 454                     "Reason: {0}, Message: {1}".format(reason, message))
#     455
#     456         raise GenericGBQException(errors)
#
# GenericGBQException: Reason: invalidQuery, Message: Syntax error: Unexpected identifier "SUM" at [11:3]

# %%
#obtain overall data for prescribing for trimethoprim capsules at CCG level
ccg_df = pd.read_gbq("""
SELECT
  trimethoprim.month as period,
  trimethoprim.pct,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
      ELSE 0 END) AS trimethoprim_items,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501130R0' THEN items
      ELSE 0 END) AS nitrofurantoin_items,
  SUM(items) AS all_items,
  IEEE_DIVIDE(SUM(
      CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
        ELSE 0 END), SUM(items)) AS trimethoprim_percent
FROM
ebmdatalab.richard.trimethoprim_data AS trimethoprim
INNER JOIN
  ebmdatalab.hscic.ccgs AS ccg
ON
  trimethoprim.pct=ccg.code
WHERE
 ccg.org_type = 'CCG'
and trimethoprim.month  >='2011-01-01 00:00:00'
GROUP BY
  period,
  pct
ORDER BY
  period,
  pct
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_pPs0v7AKWfxTK3xWx1BmKHwFKmdK
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 17316 rows.
#
# Total time taken 2.88 s.
# Finished at 2018-03-06 14:50:54.

# %%
#obtain overall data for prescribing for trimethoprim at practice level where practices with list size of => 1000
practice_df = pd.read_gbq("""
SELECT
  trimethoprim.month as period,
  trimethoprim.practice,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
      ELSE 0 END) AS trimethoprim_items,
  SUM(CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501130R0' THEN items
      ELSE 0 END) AS nitrofurantoin_items,
  SUM(items) AS all_items,
  IEEE_DIVIDE(SUM(
      CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
        ELSE 0 END), SUM(items)) AS trimethoprim_percent
FROM
  ebmdatalab.richard.trimethoprim_data AS trimethoprim
INNER JOIN
  ebmdatalab.hscic.practice_statistics_all_years AS listsize
ON
  trimethoprim.practice=listsize.practice
AND   
  trimethoprim.month=listsize.month
WHERE
  listsize.total_list_size >=1000
  and trimethoprim.month >='2011-01-01 00:00:00'
GROUP BY
  period,
  practice
ORDER BY
  period,
  practice
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_ea6f0TAFrRf0SmPSKtOnfIRDNvvX
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
#   Got page: 2; 18% done. Elapsed 12.65 s.
#   Got page: 3; 27% done. Elapsed 18.62 s.
#   Got page: 4; 36% done. Elapsed 25.14 s.
#   Got page: 5; 45% done. Elapsed 31.68 s.
#   Got page: 6; 54% done. Elapsed 38.06 s.
#   Got page: 7; 63% done. Elapsed 44.4 s.
#   Got page: 8; 72% done. Elapsed 50.08 s.
#   Got page: 9; 81% done. Elapsed 57.59 s.
#   Got page: 10; 90% done. Elapsed 64.09 s.
#   Got page: 11; 99% done. Elapsed 69.33 s.
#   Got page: 12; 100% done. Elapsed 70.73 s.
# Got 645524 rows.
#
# Total time taken 84.61 s.
# Finished at 2018-03-06 14:52:40.

# %% [markdown]
# ## Create stacked bar charts

# %% [markdown]
# ### Long-term trend bar chart

# %%
#Create additional columns for bar stacks
lt_overall_df['all_items']=lt_overall_df['trimethoprim_items']+lt_overall_df['nitrofurantoin_items']+lt_overall_df['cotrimox_items']
lt_overall_df['trimeth_and_nitro_items']=lt_overall_df['trimethoprim_items']+lt_overall_df['nitrofurantoin_items']

#Create stacked graph in Seaborn, using overlaid plots

#setup style and size
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

#plot chart
#top_plot - "all_items"  - will show "nitrofurantoin" in final plot
top_plot = sns.barplot(x="year", y="all_items",data=lt_overall_df,color = "lightsteelblue", ci=None)
#bottom_plot - "trimethoprim_items"
bottom_plot = sns.barplot(x="year", y="trimethoprim_items",data=lt_overall_df, color = "darkblue", ci=None)

#create legend
topbar = plt.Rectangle((0,0),1,1,fc="lightsteelblue", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='darkblue',  edgecolor = 'none')
l = plt.legend([bottombar, topbar], ['trimethoprim', 'nitrofurantoin'], loc=0, ncol = 32, prop={'size':16})
l.draw_frame(False)

#format axes
sns.despine(left=True)
bottom_plot.set_ylabel("Prescription items for NHS in England")
bottom_plot.set_xlabel("Year")
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(16)

# %% [markdown]
# ### Monthly trend bar chart

# %%
#Create additional columns for bar stacks
overall_df['all_items']=overall_df['trimethoprim_items']+overall_df['nitrofurantoin_items']

#Create stacked graph in Seaborn, using overlaid plots

#setup style and size
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

#plot chart
#top_plot - "all_items"  - will show "nitrofurantoin" in final plot
top_plot = sns.barplot(x="month_string", y="all_items",data=overall_df,color = "lightsteelblue", ci=None)
#bottom_plot - "trimethoprim_items"
bottom_plot = sns.barplot(x="month_string", y="trimethoprim_items",data=overall_df, color = "darkblue", ci=None)

#create legend
topbar = plt.Rectangle((0,0),1,1,fc="lightsteelblue", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='darkblue',  edgecolor = 'none')
l = plt.legend([bottombar, topbar], ['trimethoprim', 'nitrofurantoin'], loc=0, ncol = 32, prop={'size':16})
l.draw_frame(False)

#format axes
plt.xticks(rotation=90)
sns.despine(left=True)
bottom_plot.set_ylabel("Prescription items for NHS in England")
bottom_plot.set_xlabel("Month")
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(16)

# %% [markdown]
# ### Create timeseries for CCGs and practice deciles of percentage of pregabalin as Lyrica

# %%
import datetime
#create deciles for practices
x = np.arange(0.1, 1, 0.1)
practice_deciles = practice_df.groupby('period')['trimethoprim_percent'].quantile(x)
practice_deciles_df=pd.DataFrame(practice_deciles)
practice_deciles_df=practice_deciles_df.reset_index()
# create integer range of percentiles as integers are better for  charts
practice_deciles_df["index"] = (practice_deciles_df.level_1*10).map(int)
practice_deciles_df['period'] = practice_deciles_df['period'].astype(str)
# set format for dates:
practice_deciles_df['period'] = [datetime.datetime.strptime(date, '%Y-%m-%d').date() for date in practice_deciles_df['period']]

#create deciles for CCGs
x = np.arange(0.1, 1, 0.1)
ccg_deciles = ccg_df.groupby('period')['trimethoprim_percent'].quantile(x)
ccg_deciles_df=pd.DataFrame(ccg_deciles)
ccg_deciles_df=ccg_deciles_df.reset_index()
# create integer range of percentiles as integers are better for  charts
ccg_deciles_df["index"] = (ccg_deciles_df.level_1*10).map(int)
ccg_deciles_df['period'] = ccg_deciles_df['period'].astype(str)
# set format for dates:
ccg_deciles_df['period'] = [datetime.datetime.strptime(date, '%Y-%m-%d').date() for date in ccg_deciles_df['period']]

# %%
# Plot time series charts of deciles
import matplotlib.pyplot as plt
import datetime
import matplotlib.gridspec as gridspec
import seaborn as sns

sns.set_style("whitegrid",{'grid.color': '.9'})

fig = plt.figure(figsize=(16,6.666)) 
gs = gridspec.GridSpec(1,2)  # grid layout for subplots

# set sort order of drugs manually, and add grid refs to position each subplot:
s = [(0,ccg_deciles_df,0,0,'CCGs'), (1,practice_deciles_df,0,1,'practices')]

# Plot each subplot using a loop
for i in s:
    ax = plt.subplot(gs[i[2], i[3]],sharey=ax)  # position of subplot in grid using coordinates listed in s
    for decile in range(1,10):   # plot each decile line
        data = i[1].loc[(i[1]['index']==decile)]
        if decile == 5:
            ax.plot(data["period"],100*data['trimethoprim_percent'],'b-',linewidth=0.7)
        else:
            ax.plot(data["period"],100*data['trimethoprim_percent'],'b--',linewidth=0.4)
    if  i[3]%2==0:    # set y axis title only for charts in leftmost column
        ax.set_ylabel('Trimethoprim as percentage of trimethoprim and nitrofurantoin', size =15, alpha=0.6)
    ax.set_title(i[4],size = 18)
    ax.set_ylim([0, 100*i[1]['trimethoprim_percent'].max()*1.05])  # set ymax across all subplots as largest value across dataset
    ax.tick_params(labelsize=12)
    ax.set_xlim([i[1]['period'].min(), i[1]['period'].max()]) # set x axis range as full date range
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=90)
    ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%B %Y'))
    
plt.subplots_adjust(wspace = 0.07,hspace = 0.15)
#plt.savefig('Figure X.png', format='png', dpi=300)
plt.show()

# %%
#ccg_idr_df=ccg_deciles_df.pivot(index='period', columns='level_1', values='trimethoprim_percent')

# %%
#ccg_idr_df = ccg_idr_df.rename(columns={0.1:"one",0.9:"nine"})

# %%
#ccg_idr_df.head()

# %%
#ccg_idr_df["IDR"] = ccg_idr_df['nine'] - ccg_idr_df['one']

# %%
#from IPython.display import display, HTML
##pd.set_option('display.max_colwidth', -1)
#display(HTML(ccg_idr_df.to_html(header=False)))

# %%
ccg_idr_df=ccg_deciles_df.pivot(index='period', columns='level_1', values='trimethoprim_percent')
ccg_idr_df = ccg_idr_df.rename(columns={0.1:"one",0.9:"nine"})
ccg_idr_df["IDR"] = ccg_idr_df['nine'] - ccg_idr_df['one']
ccg_idr_df=ccg_idr_df.reset_index()

# %%
practice_idr_df=practice_deciles_df.pivot(index='period', columns='level_1', values='trimethoprim_percent')
practice_idr_df = practice_idr_df.rename(columns={0.1:"one",0.9:"nine"})
practice_idr_df["IDR"] = practice_idr_df['nine'] - practice_idr_df['one']
practice_idr_df=practice_idr_df.reset_index()

# %%
plt.plot_date(ccg_idr_df["period"], 100*ccg_idr_df["IDR"], linestyle= "solid")
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
plt.plot_date(practice_idr_df["period"], 100*practice_idr_df["IDR"], linestyle= "solid")
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
ccg_df.head(30000)
# Out:
#           period  pct  trimethoprim_items  nitrofurantoin_items  all_items  \
# 0     2011-01-01  00C                 731                   258        989
# 1     2011-01-01  00D                2050                   751       2801
# 2     2011-01-01  00F                  26                    11         37
# 3     2011-01-01  00J                1566                   639       2205
# 4     2011-01-01  00K                2065                   805       2870
# 5     2011-01-01  00L                2272                  1285       3557
# 6     2011-01-01  00M                1730                   582       2312
# 7     2011-01-01  00N                1059                   512       1571
# 8     2011-01-01  00P                1716                   450       2166
# 9     2011-01-01  00Q                 947                   233       1180
# 10    2011-01-01  00R                1123                   197       1320
# 11    2011-01-01  00T                1627                   651       2278
# 12    2011-01-01  00V                1205                   452       1657
# 13    2011-01-01  00W                  53                    30         83
# 14    2011-01-01  00X                 826                   115        941
# 15    2011-01-01  00Y                1570                   567       2137
# 16    2011-01-01  01A                2327                   804       3131
# 17    2011-01-01  01C                1280                   513       1793
# 18    2011-01-01  01D                1489                   442       1931
# 19    2011-01-01  01E                 902                    89        991
# 20    2011-01-01  01F                 789                   274       1063
# 21    2011-01-01  01G                1076                   891       1967
# 22    2011-01-01  01H                2166                   385       2551
# 23    2011-01-01  01J                 926                   299       1225
# 24    2011-01-01  01K                1978                   623       2601
# 25    2011-01-01  01N                  21                     8         29
# 26    2011-01-01  01R                1016                   414       1430
# 27    2011-01-01  01T                 784                   288       1072
# 28    2011-01-01  01V                 743                   192        935
# 29    2011-01-01  01W                1710                   536       2246
# ...          ...  ...                 ...                   ...        ...
# 17286 2017-11-01  10Y                 604                  1609       2213
# 17287 2017-11-01  11A                2571                  2570       5141
# 17288 2017-11-01  11C                 443                   918       1361
# 17289 2017-11-01  11D                 426                   869       1295
# 17290 2017-11-01  11E                 636                  1249       1885
# 17291 2017-11-01  11H                1722                  2479       4201
# 17292 2017-11-01  11J                2266                  5702       7968
# 17293 2017-11-01  11M                2643                  3470       6113
# 17294 2017-11-01  11N                2268                  3672       5940
# 17295 2017-11-01  11T                1041                  1219       2260
# 17296 2017-11-01  11X                1721                  2403       4124
# 17297 2017-11-01  12A                1182                  1145       2327
# 17298 2017-11-01  12D                 772                  1284       2056
# 17299 2017-11-01  12F                1543                  2056       3599
# 17300 2017-11-01  13P                1612                  4010       5622
# 17301 2017-11-01  13T                1517                  3075       4592
# 17302 2017-11-01  14L                2304                  2713       5017
# 17303 2017-11-01  99A                1534                  2594       4128
# 17304 2017-11-01  99C                 819                  1248       2067
# 17305 2017-11-01  99D                 743                  1216       1959
# 17306 2017-11-01  99E                1503                   964       2467
# 17307 2017-11-01  99F                 894                   744       1638
# 17308 2017-11-01  99G                 780                   691       1471
# 17309 2017-11-01  99H                 886                  1887       2773
# 17310 2017-11-01  99J                1939                  2910       4849
# 17311 2017-11-01  99K                 553                  1145       1698
# 17312 2017-11-01  99M                 805                  1281       2086
# 17313 2017-11-01  99N                1978                  3452       5430
# 17314 2017-11-01  99P                3838                  5529       9367
# 17315 2017-11-01  99Q                1370                  1495       2865
#
#        trimethoprim_percent
# 0                  0.739130
# 1                  0.731881
# 2                  0.702703
# 3                  0.710204
# 4                  0.719512
# 5                  0.638741
# 6                  0.748270
# 7                  0.674093
# 8                  0.792244
# 9                  0.802542
# 10                 0.850758
# 11                 0.714223
# 12                 0.727218
# 13                 0.638554
# 14                 0.877790
# 15                 0.734675
# 16                 0.743213
# 17                 0.713887
# 18                 0.771103
# 19                 0.910192
# 20                 0.742239
# 21                 0.547026
# 22                 0.849079
# 23                 0.755918
# 24                 0.760477
# 25                 0.724138
# 26                 0.710490
# 27                 0.731343
# 28                 0.794652
# 29                 0.761354
# ...                     ...
# 17286              0.272933
# 17287              0.500097
# 17288              0.325496
# 17289              0.328958
# 17290              0.337401
# 17291              0.409902
# 17292              0.284388
# 17293              0.432357
# 17294              0.381818
# 17295              0.460619
# 17296              0.417313
# 17297              0.507950
# 17298              0.375486
# 17299              0.428730
# 17300              0.286731
# 17301              0.330357
# 17302              0.459239
# 17303              0.371609
# 17304              0.396226
# 17305              0.379275
# 17306              0.609242
# 17307              0.545788
# 17308              0.530252
# 17309              0.319510
# 17310              0.399876
# 17311              0.325677
# 17312              0.385906
# 17313              0.364273
# 17314              0.409736
# 17315              0.478185
#
# [17316 rows x 6 columns]

# %%
pre_ccg_df=ccg_df.loc['2014-01-01':'2014-06-01']

# %%
pre_ccg_df.head()
# Out:
# Empty DataFrame
# Columns: [period, pct, trimethoprim_items, nitrofurantoin_items, all_items, trimethoprim_percent]
# Index: []

# %%
#obtain overall data for prescribing for trimethoprim capsules at CCG level
ccg_pre_df = pd.read_gbq("""
SELECT
  trimethoprim.pct,
  IEEE_DIVIDE(SUM(
      CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
        ELSE 0 END), SUM(items)) AS trimethoprim_percent
FROM
ebmdatalab.richard.trimethoprim_data AS trimethoprim
INNER JOIN
  ebmdatalab.hscic.ccgs AS ccg
ON
  trimethoprim.pct=ccg.code
WHERE
 ccg.org_type = 'CCG'
and (trimethoprim.month >='2014-01-01 00:00:00' and trimethoprim.month <= '2014-06-01 00:00:00')
GROUP BY
  pct
ORDER BY
  pct
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_pvHniIk0z4Bba5GrS1JB2I1K3ioZ
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 209 rows.
#
# Total time taken 1.13 s.
# Finished at 2018-03-06 14:53:21.

# %%
#obtain overall data for prescribing for trimethoprim capsules at CCG level
ccg_post_df = pd.read_gbq("""
SELECT
  trimethoprim.pct,
  IEEE_DIVIDE(SUM(
      CASE
      WHEN SUBSTR(trimethoprim.bnf_code,1,9)='0501080W0' THEN items
        ELSE 0 END), SUM(items)) AS trimethoprim_percent
FROM
ebmdatalab.richard.trimethoprim_data AS trimethoprim
INNER JOIN
  ebmdatalab.hscic.ccgs AS ccg
ON
  trimethoprim.pct=ccg.code
WHERE
 ccg.org_type = 'CCG'
and (trimethoprim.month >='2017-06-01 00:00:00' and trimethoprim.month <= '2017-06-01 00:00:00')
GROUP BY
  pct
ORDER BY
  pct
""", projectid, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_-2DarBb7Xk4Jmh-vSZhqatMnzVqM
# Query running...
# Query done.
# Processed: 148.2 MB
# Standard price: $0.00 USD
#
# Retrieving results...
# Got 207 rows.
#
# Total time taken 5.37 s.
# Finished at 2018-03-06 14:56:52.

# %%
# join to geographical data
pre_map_data = ccg_pre_df.reset_index()
names = pd.read_csv('https://raw.githubusercontent.com/ebmdatalab/jupyter-notebooks/master/antibiotics/ccg_for_map.csv')
pre_map_data = pre_map_data.merge(names[['code','name']],left_on="pct",right_on="code")
pre_map_data['name'] = pre_map_data['name'].str.upper()
pre_map_data['name'] = pre_map_data["name"].str.replace("&","AND")
pre_map_data = pre_map_data.set_index('name')
#pre_map_data= pre_map_data.rename(columns={'trimethoprim_percent':"Trimethoprim % January-June 2014"})
#map_data = map_data.round(0)
pre_map_data.head() # 207 rows

post_map_data = ccg_post_df.reset_index()
names = pd.read_csv('https://raw.githubusercontent.com/ebmdatalab/jupyter-notebooks/master/antibiotics/ccg_for_map.csv')
post_map_data = post_map_data.merge(names[['code','name']],left_on="pct",right_on="code")
post_map_data['name'] = post_map_data['name'].str.upper()
post_map_data['name'] = post_map_data["name"].str.replace("&","AND")
post_map_data = post_map_data.set_index('name')
#post_map_data= post_map_data.rename(columns={'trimethoprim_percent':"Trimethoprim % June-November 2017"})
#map_data = map_data.round(0)
#post_map_data.head() # 207 rows

# %%
pre_map_data.head()
# Out:
#                                                 index  pct  \
# name
# NHS DARLINGTON CCG                                  0  00C
# NHS DURHAM DALES, EASINGTON AND SEDGEFIELD CCG      1  00D
# NHS NORTH DURHAM CCG                                2  00J
# NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG             3  00K
# NHS NORTHUMBERLAND CCG                              4  00L
#
#                                                 trimethoprim_percent code
# name
# NHS DARLINGTON CCG                                          0.709735  00C
# NHS DURHAM DALES, EASINGTON AND SEDGEFIELD CCG              0.669403  00D
# NHS NORTH DURHAM CCG                                        0.686842  00J
# NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG                     0.681696  00K
# NHS NORTHUMBERLAND CCG                                      0.621627  00L

# %%
import geopandas as gpd
from matplotlib import verbose
# from our API https://openprescribing.net/api/1.0/org_location/?org_type=ccg
ccgs = gpd.read_file('ccgs.json').set_index('name')

ccgs = ccgs[~ccgs['geometry'].isnull()]  # remove ones without geometry - these are federations rather than individual CCGs
gdf_post = ccgs.join(post_map_data)
gdf_pre = ccgs.join(pre_map_data)

# set sort order of measures manually, and add grid refs to position each subplot:
s_post = [(1,'trimethoprim_percent',0,1)]
s_pre = [(0,'trimethoprim_percent',0,0)]
# set common value limits for colour scale
vmin, vmax = 0, 1

fig = plt.figure(figsize=(16,30))
gs = gridspec.GridSpec(4,2)  # grid layout for subplots

for i in s_post:
    ax = plt.subplot(gs[i[2], i[3]])  # position of subplot in grid using coordinates listed in s
    gdf_post.plot(ax=ax,column=i[1],  edgecolor='black', linewidth=0.1, legend=True, cmap='coolwarm',vmin=vmin, vmax=vmax)
    ax.set_aspect(1.63)
    ax.set_title("June-November 2017", size=16)
    plt.axis('off')
for i in s_pre:
    ax = plt.subplot(gs[i[2], i[3]])  # position of subplot in grid using coordinates listed in s
    gdf_pre.plot(ax=ax,column=i[1],  edgecolor='black', linewidth=0.1, legend=False, cmap='coolwarm',vmin=vmin, vmax=vmax)
    ax.set_aspect(1.63)
    ax.set_title("January-June 2014",size = 16)
    plt.axis('off')

plt.subplots_adjust(wspace = 0.05,hspace = 0.05)
plt.savefig('maps.png', format='png', dpi=300,bbox_inches='tight')

plt.show()

# %%
# resistance data with map

resistance_df=pd.read_csv('resistance_q3_2017.csv')

# %%
resistance_df.head()
# Out:
#                                       CCG      Value
# 0  NHS AIREDALE, WHARFDALE AND CRAVEN CCG  30.434781
# 1                         NHS ASHFORD CCG  20.245399
# 2                  NHS AYLESBURY VALE CCG  27.500001
# 3            NHS BARKING AND DAGENHAM CCG  26.146790
# 4                          NHS BARNET CCG  32.921812

# %%
names = pd.read_csv('https://raw.githubusercontent.com/ebmdatalab/jupyter-notebooks/master/antibiotics/ccg_for_map.csv')
resistance_map_data = resistance_df(names[['CCG']],left_on="pct")
pre_map_data['name'] = pre_map_data['name'].str.upper()
pre_map_data['name'] = pre_map_data["name"].str.replace("&","AND")
pre_map_data = pre_map_data.set_index('name')
#pre_map_data= pre_map_data.rename(columns={'trimethoprim_percent':"Trimethoprim % January-June 2014"})
#map_data = map_data.round(0)
pre_map_data.head() # 207 rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-90f3b3c626fe> in <module>()
#       1
#       2 names = pd.read_csv('https://raw.githubusercontent.com/ebmdatalab/jupyter-notebooks/master/antibiotics/ccg_for_map.csv')
# ----> 3 resistance_map_data = resistance_df(names[['CCG']],left_on="pct")
#       4 pre_map_data['name'] = pre_map_data['name'].str.upper()
#       5 pre_map_data['name'] = pre_map_data["name"].str.replace("&","AND")
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# C:\Users\racro\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['CCG'] not in index"
